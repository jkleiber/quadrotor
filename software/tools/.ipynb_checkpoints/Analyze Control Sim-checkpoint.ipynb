# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def load_csv(file):
    # File locations
    log_path = "../build/src/control_sim/" + file

    csv_df = pd.read_csv(log_path)
    csv_df.columns = csv_df.columns.str.replace(" ","")

    return csv_df

# %%
# Load quadcopter state
x_df = load_csv("state_log.csv")
x_df.head()
# Out:
#    time         u         v         w         p         q         r         x  \
# 0  0.00  0.000000  0.000000 -0.099074 -0.017028  0.044043  0.004544  0.000000
# 1  0.01  0.000044  0.000017 -0.069745 -0.044282  0.041597 -0.002519  0.000000
# 2  0.02  0.000029  0.000031 -0.036514 -0.000745 -0.073140  0.008083  0.000000
# 3  0.03 -0.000081 -0.000029 -0.004937  0.196235 -0.205701 -0.003481  0.000000
# 4  0.04 -0.000104 -0.000099  0.023372  0.121308  0.031628 -0.027070 -0.000001
#
#      y         z      roll     pitch       yaw
# 0  0.0  0.000000  0.000000  0.000000  0.000000
# 1  0.0 -0.000991 -0.000170  0.000440  0.000045
# 2  0.0 -0.001688 -0.000613  0.000856  0.000020
# 3  0.0 -0.002053 -0.000620  0.000125  0.000101
# 4 -0.0 -0.002103  0.001342 -0.001932  0.000068

# %%
x_df.columns
# Out:
# Index(['time', 'u', 'v', 'w', 'p', 'q', 'r', 'x', 'y', 'z', 'roll', 'pitch',
#        'yaw'],
#       dtype='object')

# %%
# Time
t_df = x_df['time']
t = t_df.to_numpy()

# Height DF -> Numpy
z_df = x_df['z']
z_np = z_df.to_numpy()

# Roll / Pitch / Yaw - DF -> Numpy
rpy_df = x_df[['roll','pitch','yaw']]
rpy_np = rpy_df.to_numpy()

# %%
# Plotting indices
idx_start = 0
idx_end = 400

# Clip variables
t_clip = t[idx_start:idx_end]
z = z_np[idx_start:idx_end]
roll = rpy_np[idx_start:idx_end, 0]
pitch = rpy_np[idx_start:idx_end, 1]
yaw = rpy_np[idx_start:idx_end, 2]

# Convert RPY to degrees
roll = np.degrees(roll)
pitch = np.degrees(pitch)
yaw = np.degrees(yaw)


# Plotting RPY
f, axs = plt.subplots(3, sharex=True)

axs[0].plot(t_clip, roll)
axs[0].set_ylabel("Roll (deg)")

axs[1].plot(t_clip, pitch)
axs[1].set_ylabel("Pitch (deg)")

axs[2].plot(t_clip, yaw)
axs[2].set_ylabel("Yaw (deg)")
axs[2].set_xlabel("Time (s)")

f.tight_layout()

plt.show()

# Plotting height
plt.plot(t_clip, z)
plt.title("Height")
plt.ylabel("Height (m)")
plt.xlabel("Time (s)")
plt.show()

# %% [markdown]
# # Control Effort

# %%
# Load motor throttle
motor_df = load_csv("ctrl_log.csv")

# %%
# Get motor data
t_mot = motor_df['time']
t_mot = t_mot.to_numpy()

motor_np = motor_df[['motor_fr', 'motor_bl', 'motor_fl', 'motor_br']].to_numpy()

# %%
# Clip to the boundaries

t_mot_clip = t_mot[idx_start:idx_end]
motor_clip = motor_np[idx_start:idx_end,:]


plt.plot(t_mot_clip, motor_clip)
plt.show()
